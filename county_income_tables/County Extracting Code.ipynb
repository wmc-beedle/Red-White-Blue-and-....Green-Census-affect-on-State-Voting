# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import scipy.stats as stats
import seaborn as sea
from sklearn.metrics import log_loss, make_scorer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# max_v = ipt.groupby(['year', 'state'])['candidatevotes'].transform(func=max)
# president = president.reset_index().set_index(['year', 'county'])
# income.to_csv(r'county_income_2000-2016.xlsx')
# dfs = [df.set_index(['year', 'county']) for df in income.values()]
# president_income = president.merge(income, left_on='state', right_on='State', how='left')
# president_income = president_income.reset_index().set_index(['year','state'])
# pd.set_option('display.max_rows', None)

# %%
president = pd.read_csv('voting_2000_2016_county_data.csv', index_col=1)

# %%
# Import data


for i in range(2010,2017):
    file = pd.read_csv('county_income_{year}.csv'.format(year=str(i)),header=1)
    del file['id']
    file['Geographic Area Name'] = file['Geographic Area Name'].apply(lambda x: x.split('County')[0])
    file['year'] = i
    file.rename(columns = {'Geographic Area Name':'county'}, inplace = True)
    file.set_index(['year', 'county'])
    president += president.merge(file, on=['county'], how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-0ab01e6d9437> in <module>
#       9     file.rename(columns = {'Geographic Area Name':'county'}, inplace = True)
#      10     file.set_index(['year', 'county'])
# ---> 11     president += president.merge(file, on=['county'], how='outer')
#      12
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/ops/methods.py in f(self, other)
#      99             # we are updating inplace so we want to ignore is_copy
#     100             self._update_inplace(
# --> 101                 result.reindex_like(self, copy=False), verify_is_copy=False
#     102             )
#     103
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in reindex_like(self, other, method, copy, limit, tolerance)
#    3854         )
#    3855
# -> 3856         return self.reindex(**d)
#    3857
#    3858     def drop(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    4030         kwargs.pop("axis", None)
#    4031         kwargs.pop("labels", None)
# -> 4032         return super().reindex(**kwargs)
#    4033
#    4034     def drop(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4459
#    4460         # perform the reindex on the axes
# -> 4461         return self._reindex_axes(
#    4462             axes, level, limit, tolerance, method, fill_value, copy
#    4463         ).__finalize__(self, method="reindex")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3876         index = axes["index"]
#    3877         if index is not None:
# -> 3878             frame = frame._reindex_index(
#    3879                 index, method, copy, level, fill_value, limit, tolerance
#    3880             )
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _reindex_index(self, new_index, method, copy, level, fill_value, limit, tolerance)
#    3895             new_index, method=method, level=level, limit=limit, tolerance=tolerance
#    3896         )
# -> 3897         return self._reindex_with_indexers(
#    3898             {0: [new_index, indexer]},
#    3899             copy=copy,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    4522
#    4523             # TODO: speed up on homogeneous DataFrame objects
# -> 4524             new_data = new_data.reindex_indexer(
#    4525                 index,
#    4526                 indexer,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1274         # some axes don't allow reindexing with dups
#    1275         if not allow_dups:
# -> 1276             self.axes[axis]._can_reindex(indexer)
#    1277
#    1278         if axis >= self.ndim:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3287         # trying to reindex on an axis with duplicates
#    3288         if not self.is_unique and len(indexer):
# -> 3289             raise ValueError("cannot reindex from a duplicate axis")
#    3290
#    3291     def reindex(self, target, method=None, level=None, limit=None, tolerance=None):
#
# ValueError: cannot reindex from a duplicate axis

# %%
president_income = president.merge(income, on=['year','state'], how='outer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-beaced3f795e> in <module>
# ----> 1 president_income = president.merge(income, on=['year','state'], how='outer')
#
# NameError: name 'income' is not defined

# %%
president.head()
# Out:
#          year state_po   county    FIPS     office       candidate  \
# state
# Alabama  2000       AL  Autauga  1001.0  President         Al Gore
# Alabama  2000       AL  Autauga  1001.0  President  George W. Bush
# Alabama  2000       AL  Autauga  1001.0  President     Ralph Nader
# Alabama  2000       AL  Autauga  1001.0  President           Other
# Alabama  2000       AL  Baldwin  1003.0  President         Al Gore
#
#               party  candidatevotes  totalvotes   version
# state
# Alabama    democrat          4942.0       17208  20191203
# Alabama  republican         11993.0       17208  20191203
# Alabama       green           160.0       17208  20191203
# Alabama         NaN           113.0       17208  20191203
# Alabama    democrat         13997.0       56480  20191203

# %%
file = pd.read_csv('county_income_2012.csv', header=1)
file = pd.DataFrame(file)

file['Geographic Area Name'] = file['Geographic Area Name'].apply(lambda x: x.split('County')[0])
del file['id']
file.rename(columns = {'Geographic Area Name':'county'}, inplace = True)
file['year'] = 2012

# %%
# Import data
income = file

# %%
income.to_csv(r'county_income_2000-2016.csv')

# %%
# file = pd.read_csv('county_income_2010.csv', header=1, index_col=1)
# file = pd.DataFrame(file)
# file.index.names=['county']
# file.rename(index=str.lower)
# del file['id']

# file.head()

# %%
president_income = president_income.reset_index().set_index(['year','state'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0c350bff2aad> in <module>
# ----> 1 president_income = president_income.reset_index().set_index(['year','state'])
#
# NameError: name 'president_income' is not defined

# %%
# president.rename(columns={'year':'year_x'}, inplace = True)

# %%
president['year_x']>=2010
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year_x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-d7abbcbeef12> in <module>
# ----> 1 president['year_x']>=2010
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'year_x'

# %%
income.set_index(['county', 'year'], inplace=True)

# %%
income
# Out:
#                                            Total!!Estimate!!Households  \
# county                               year
# Ouachita Parish, Louisiana           2012                        58133
# Rapides Parish, Louisiana            2012                        49299
# St. Landry Parish, Louisiana         2012                        30937
# St. Tammany Parish, Louisiana        2012                        89333
# Tangipahoa Parish, Louisiana         2012                        43653
# ...                                                                ...
# Toa Alta Municipio, Puerto Rico      2012                        22503
# Toa Baja Municipio, Puerto Rico      2012                        30086
# Trujillo Alto Municipio, Puerto Rico 2012                        25031
# Bayamón Municipio, Puerto Rico       2012                        71871
# Mayagüez Municipio, Puerto Rico      2012                        31216
#
#                                            Total!!Margin of Error!!Households  \
# county                               year
# Ouachita Parish, Louisiana           2012                                1702
# Rapides Parish, Louisiana            2012                                1669
# St. Landry Parish, Louisiana         2012                                1042
# St. Tammany Parish, Louisiana        2012                                1323
# Tangipahoa Parish, Louisiana         2012                                1545
# ...                                                                       ...
# Toa Alta Municipio, Puerto Rico      2012                                1103
# Toa Baja Municipio, Puerto Rico      2012                                1080
# Trujillo Alto Municipio, Puerto Rico 2012                                1178
# Bayamón Municipio, Puerto Rico       2012                                2064
# Mayagüez Municipio, Puerto Rico      2012                                1340
#
#                                            Total!!Estimate!!One race!!White  \
# county                               year
# Ouachita Parish, Louisiana           2012                              64.3
# Rapides Parish, Louisiana            2012                              68.7
# St. Landry Parish, Louisiana         2012                              60.4
# St. Tammany Parish, Louisiana        2012                              85.8
# Tangipahoa Parish, Louisiana         2012                              73.2
# ...                                                                     ...
# Toa Alta Municipio, Puerto Rico      2012                              62.5
# Toa Baja Municipio, Puerto Rico      2012                              48.8
# Trujillo Alto Municipio, Puerto Rico 2012                              57.5
# Bayamón Municipio, Puerto Rico       2012                              59.8
# Mayagüez Municipio, Puerto Rico      2012                              55.1
#
#                                            Total!!Margin of Error!!One race!!White  \
# county                               year
# Ouachita Parish, Louisiana           2012                                      1.7
# Rapides Parish, Louisiana            2012                                      2.0
# St. Landry Parish, Louisiana         2012                                      1.9
# St. Tammany Parish, Louisiana        2012                                      0.9
# Tangipahoa Parish, Louisiana         2012                                      2.2
# ...                                                                            ...
# Toa Alta Municipio, Puerto Rico      2012                                      5.5
# Toa Baja Municipio, Puerto Rico      2012                                      4.5
# Trujillo Alto Municipio, Puerto Rico 2012                                      4.5
# Bayamón Municipio, Puerto Rico       2012                                      2.6
# Mayagüez Municipio, Puerto Rico      2012                                      4.3
#
#                                           Total!!Estimate!!One race!!Black or African American  \
# county                               year
# Ouachita Parish, Louisiana           2012                                               33.7
# Rapides Parish, Louisiana            2012                                               28.5
# St. Landry Parish, Louisiana         2012                                               37.4
# St. Tammany Parish, Louisiana        2012                                               10.3
# Tangipahoa Parish, Louisiana         2012                                               25.2
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                  N
# Toa Baja Municipio, Puerto Rico      2012                                                9.6
# Trujillo Alto Municipio, Puerto Rico 2012                                                7.5
# Bayamón Municipio, Puerto Rico       2012                                                7.8
# Mayagüez Municipio, Puerto Rico      2012                                                  N
#
#                                           Total!!Margin of Error!!One race!!Black or African American  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                1.7
# Rapides Parish, Louisiana            2012                                                1.9
# St. Landry Parish, Louisiana         2012                                                2.6
# St. Tammany Parish, Louisiana        2012                                                0.8
# Tangipahoa Parish, Louisiana         2012                                                2.4
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                  N
# Toa Baja Municipio, Puerto Rico      2012                                                2.2
# Trujillo Alto Municipio, Puerto Rico 2012                                                2.6
# Bayamón Municipio, Puerto Rico       2012                                                1.3
# Mayagüez Municipio, Puerto Rico      2012                                                  N
#
#                                           Total!!Estimate!!One race!!American Indian and Alaska Native  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                  N
# Rapides Parish, Louisiana            2012                                                  N
# St. Landry Parish, Louisiana         2012                                                  N
# St. Tammany Parish, Louisiana        2012                                                  N
# Tangipahoa Parish, Louisiana         2012                                                  N
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                  N
# Toa Baja Municipio, Puerto Rico      2012                                                  N
# Trujillo Alto Municipio, Puerto Rico 2012                                                  N
# Bayamón Municipio, Puerto Rico       2012                                                  N
# Mayagüez Municipio, Puerto Rico      2012                                                  N
#
#                                           Total!!Margin of Error!!One race!!American Indian and Alaska Native  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                  N
# Rapides Parish, Louisiana            2012                                                  N
# St. Landry Parish, Louisiana         2012                                                  N
# St. Tammany Parish, Louisiana        2012                                                  N
# Tangipahoa Parish, Louisiana         2012                                                  N
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                  N
# Toa Baja Municipio, Puerto Rico      2012                                                  N
# Trujillo Alto Municipio, Puerto Rico 2012                                                  N
# Bayamón Municipio, Puerto Rico       2012                                                  N
# Mayagüez Municipio, Puerto Rico      2012                                                  N
#
#                                           Total!!Estimate!!One race!!Asian  \
# county                               year
# Ouachita Parish, Louisiana           2012                                N
# Rapides Parish, Louisiana            2012                                N
# St. Landry Parish, Louisiana         2012                                N
# St. Tammany Parish, Louisiana        2012                                N
# Tangipahoa Parish, Louisiana         2012                                N
# ...                                                                    ...
# Toa Alta Municipio, Puerto Rico      2012                                N
# Toa Baja Municipio, Puerto Rico      2012                                N
# Trujillo Alto Municipio, Puerto Rico 2012                                N
# Bayamón Municipio, Puerto Rico       2012                                N
# Mayagüez Municipio, Puerto Rico      2012                                N
#
#                                           Total!!Margin of Error!!One race!!Asian  \
# county                               year
# Ouachita Parish, Louisiana           2012                                       N
# Rapides Parish, Louisiana            2012                                       N
# St. Landry Parish, Louisiana         2012                                       N
# St. Tammany Parish, Louisiana        2012                                       N
# Tangipahoa Parish, Louisiana         2012                                       N
# ...                                                                           ...
# Toa Alta Municipio, Puerto Rico      2012                                       N
# Toa Baja Municipio, Puerto Rico      2012                                       N
# Trujillo Alto Municipio, Puerto Rico 2012                                       N
# Bayamón Municipio, Puerto Rico       2012                                       N
# Mayagüez Municipio, Puerto Rico      2012                                       N
#
#                                            ...  \
# county                               year  ...
# Ouachita Parish, Louisiana           2012  ...
# Rapides Parish, Louisiana            2012  ...
# St. Landry Parish, Louisiana         2012  ...
# St. Tammany Parish, Louisiana        2012  ...
# Tangipahoa Parish, Louisiana         2012  ...
# ...                                        ...
# Toa Alta Municipio, Puerto Rico      2012  ...
# Toa Baja Municipio, Puerto Rico      2012  ...
# Trujillo Alto Municipio, Puerto Rico 2012  ...
# Bayamón Municipio, Puerto Rico       2012  ...
# Mayagüez Municipio, Puerto Rico      2012  ...
#
#                                           Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Living alone  \
# county                               year
# Ouachita Parish, Louisiana           2012                                               7436
# Rapides Parish, Louisiana            2012                                               3860
# St. Landry Parish, Louisiana         2012                                               4320
# St. Tammany Parish, Louisiana        2012                                               4177
# Tangipahoa Parish, Louisiana         2012                                               5603
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                               2832
# Toa Baja Municipio, Puerto Rico      2012                                               2313
# Trujillo Alto Municipio, Puerto Rico 2012                                               2695
# Bayamón Municipio, Puerto Rico       2012                                               2831
# Mayagüez Municipio, Puerto Rico      2012                                               3448
#
#                                           Median income (dollars)!!Estimate!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# county                               year
# Ouachita Parish, Louisiana           2012                                              36425
# Rapides Parish, Louisiana            2012                                              42733
# St. Landry Parish, Louisiana         2012                                              30710
# St. Tammany Parish, Louisiana        2012                                              54475
# Tangipahoa Parish, Louisiana         2012                                              53073
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                              10799
# Toa Baja Municipio, Puerto Rico      2012                                              35960
# Trujillo Alto Municipio, Puerto Rico 2012                                              44948
# Bayamón Municipio, Puerto Rico       2012                                              19709
# Mayagüez Municipio, Puerto Rico      2012                                               4123
#
#                                           Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# county                               year
# Ouachita Parish, Louisiana           2012                                              10827
# Rapides Parish, Louisiana            2012                                              12754
# St. Landry Parish, Louisiana         2012                                              19621
# St. Tammany Parish, Louisiana        2012                                              37906
# Tangipahoa Parish, Louisiana         2012                                              44212
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                               1607
# Toa Baja Municipio, Puerto Rico      2012                                              21390
# Trujillo Alto Municipio, Puerto Rico 2012                                              86981
# Bayamón Municipio, Puerto Rico       2012                                              24633
# Mayagüez Municipio, Puerto Rico      2012                                              10430
#
#                                           Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Household income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Family income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# county                               year
# Ouachita Parish, Louisiana           2012                                                (X)
# Rapides Parish, Louisiana            2012                                                (X)
# St. Landry Parish, Louisiana         2012                                                (X)
# St. Tammany Parish, Louisiana        2012                                                (X)
# Tangipahoa Parish, Louisiana         2012                                                (X)
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                                (X)
# Toa Baja Municipio, Puerto Rico      2012                                                (X)
# Trujillo Alto Municipio, Puerto Rico 2012                                                (X)
# Bayamón Municipio, Puerto Rico       2012                                                (X)
# Mayagüez Municipio, Puerto Rico      2012                                                (X)
#
#                                           Median income (dollars)!!Margin of Error!!One race!!American Indian and Alaska Native
# county                               year
# Ouachita Parish, Louisiana           2012                                                  N
# Rapides Parish, Louisiana            2012                                              26004
# St. Landry Parish, Louisiana         2012                                                 **
# St. Tammany Parish, Louisiana        2012                                              13836
# Tangipahoa Parish, Louisiana         2012                                              21256
# ...                                                                                      ...
# Toa Alta Municipio, Puerto Rico      2012                                               6440
# Toa Baja Municipio, Puerto Rico      2012                                                 **
# Trujillo Alto Municipio, Puerto Rico 2012                                                 **
# Bayamón Municipio, Puerto Rico       2012                                               7861
# Mayagüez Municipio, Puerto Rico      2012                                                 **
#
# [825 rows x 120 columns]

# %%
# president_income = president.merge(income, left_on='state', right_on='State', how='left')
# president_income = president_income.reset_index().set_index(['year','state'])
for i in range(2010,2017):
    print('county_income_{year}.csv'.format(year=str(i)))
# Out:
# county_income_2010.csv
# county_income_2011.csv
# county_income_2012.csv
# county_income_2013.csv
# county_income_2014.csv
# county_income_2015.csv
# county_income_2016.csv

# %%
# president_income = president.merge(income, left_on='state', right_on='State', how='left')
# president_income = president_income.reset_index().set_index(['year','state'])
income = file
president_income = president.merge(income, left_on='county', right_on='county', how='left')
president_income.tail()
# Out:
#        year state_po       county    FIPS     office        candidate  \
# 50519  2016       AK  District 40  2040.0  President     Donald Trump
# 50520  2016       AK  District 40  2040.0  President            Other
# 50521  2016      NaN  District 99  2099.0  President  Hillary Clinton
# 50522  2016      NaN  District 99  2099.0  President     Donald Trump
# 50523  2016      NaN  District 99  2099.0  President            Other
#
#             party  candidatevotes  totalvotes   version  ...  \
# 50519  republican          1377.0        4610  20191203  ...
# 50520         NaN           895.0        4610  20191203  ...
# 50521    democrat           274.0        5056  20191203  ...
# 50522  republican            40.0        5056  20191203  ...
# 50523         NaN            28.0        5056  20191203  ...
#
#        Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Living alone  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#        Median income (dollars)!!Estimate!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#        Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#        Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Household income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Family income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
#       Median income (dollars)!!Margin of Error!!One race!!American Indian and Alaska Native
# 50519                                                NaN
# 50520                                                NaN
# 50521                                                NaN
# 50522                                                NaN
# 50523                                                NaN
#
# [5 rows x 130 columns]

# %%
income.head()
# Out:
#                                     Total!!Estimate!!Households  \
# county                        year
# Ouachita Parish, Louisiana    2012                        58133
# Rapides Parish, Louisiana     2012                        49299
# St. Landry Parish, Louisiana  2012                        30937
# St. Tammany Parish, Louisiana 2012                        89333
# Tangipahoa Parish, Louisiana  2012                        43653
#
#                                     Total!!Margin of Error!!Households  \
# county                        year
# Ouachita Parish, Louisiana    2012                                1702
# Rapides Parish, Louisiana     2012                                1669
# St. Landry Parish, Louisiana  2012                                1042
# St. Tammany Parish, Louisiana 2012                                1323
# Tangipahoa Parish, Louisiana  2012                                1545
#
#                                     Total!!Estimate!!One race!!White  \
# county                        year
# Ouachita Parish, Louisiana    2012                              64.3
# Rapides Parish, Louisiana     2012                              68.7
# St. Landry Parish, Louisiana  2012                              60.4
# St. Tammany Parish, Louisiana 2012                              85.8
# Tangipahoa Parish, Louisiana  2012                              73.2
#
#                                     Total!!Margin of Error!!One race!!White  \
# county                        year
# Ouachita Parish, Louisiana    2012                                      1.7
# Rapides Parish, Louisiana     2012                                      2.0
# St. Landry Parish, Louisiana  2012                                      1.9
# St. Tammany Parish, Louisiana 2012                                      0.9
# Tangipahoa Parish, Louisiana  2012                                      2.2
#
#                                    Total!!Estimate!!One race!!Black or African American  \
# county                        year
# Ouachita Parish, Louisiana    2012                                               33.7
# Rapides Parish, Louisiana     2012                                               28.5
# St. Landry Parish, Louisiana  2012                                               37.4
# St. Tammany Parish, Louisiana 2012                                               10.3
# Tangipahoa Parish, Louisiana  2012                                               25.2
#
#                                    Total!!Margin of Error!!One race!!Black or African American  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                1.7
# Rapides Parish, Louisiana     2012                                                1.9
# St. Landry Parish, Louisiana  2012                                                2.6
# St. Tammany Parish, Louisiana 2012                                                0.8
# Tangipahoa Parish, Louisiana  2012                                                2.4
#
#                                    Total!!Estimate!!One race!!American Indian and Alaska Native  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                  N
# Rapides Parish, Louisiana     2012                                                  N
# St. Landry Parish, Louisiana  2012                                                  N
# St. Tammany Parish, Louisiana 2012                                                  N
# Tangipahoa Parish, Louisiana  2012                                                  N
#
#                                    Total!!Margin of Error!!One race!!American Indian and Alaska Native  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                  N
# Rapides Parish, Louisiana     2012                                                  N
# St. Landry Parish, Louisiana  2012                                                  N
# St. Tammany Parish, Louisiana 2012                                                  N
# Tangipahoa Parish, Louisiana  2012                                                  N
#
#                                    Total!!Estimate!!One race!!Asian  \
# county                        year
# Ouachita Parish, Louisiana    2012                                N
# Rapides Parish, Louisiana     2012                                N
# St. Landry Parish, Louisiana  2012                                N
# St. Tammany Parish, Louisiana 2012                                N
# Tangipahoa Parish, Louisiana  2012                                N
#
#                                    Total!!Margin of Error!!One race!!Asian  \
# county                        year
# Ouachita Parish, Louisiana    2012                                       N
# Rapides Parish, Louisiana     2012                                       N
# St. Landry Parish, Louisiana  2012                                       N
# St. Tammany Parish, Louisiana 2012                                       N
# Tangipahoa Parish, Louisiana  2012                                       N
#
#                                     ...  \
# county                        year  ...
# Ouachita Parish, Louisiana    2012  ...
# Rapides Parish, Louisiana     2012  ...
# St. Landry Parish, Louisiana  2012  ...
# St. Tammany Parish, Louisiana 2012  ...
# Tangipahoa Parish, Louisiana  2012  ...
#
#                                    Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Living alone  \
# county                        year
# Ouachita Parish, Louisiana    2012                                               7436
# Rapides Parish, Louisiana     2012                                               3860
# St. Landry Parish, Louisiana  2012                                               4320
# St. Tammany Parish, Louisiana 2012                                               4177
# Tangipahoa Parish, Louisiana  2012                                               5603
#
#                                    Median income (dollars)!!Estimate!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# county                        year
# Ouachita Parish, Louisiana    2012                                              36425
# Rapides Parish, Louisiana     2012                                              42733
# St. Landry Parish, Louisiana  2012                                              30710
# St. Tammany Parish, Louisiana 2012                                              54475
# Tangipahoa Parish, Louisiana  2012                                              53073
#
#                                    Median income (dollars)!!Margin of Error!!NONFAMILY HOUSEHOLDS!!Male householder!!Not living alone  \
# county                        year
# Ouachita Parish, Louisiana    2012                                              10827
# Rapides Parish, Louisiana     2012                                              12754
# St. Landry Parish, Louisiana  2012                                              19621
# St. Tammany Parish, Louisiana 2012                                              37906
# Tangipahoa Parish, Louisiana  2012                                              44212
#
#                                    Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Household income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Household income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Family income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Family income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Estimate!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Margin of Error!!PERCENT IMPUTED!!Nonfamily income in the past 12 months  \
# county                        year
# Ouachita Parish, Louisiana    2012                                                (X)
# Rapides Parish, Louisiana     2012                                                (X)
# St. Landry Parish, Louisiana  2012                                                (X)
# St. Tammany Parish, Louisiana 2012                                                (X)
# Tangipahoa Parish, Louisiana  2012                                                (X)
#
#                                    Median income (dollars)!!Margin of Error!!One race!!American Indian and Alaska Native
# county                        year
# Ouachita Parish, Louisiana    2012                                                  N
# Rapides Parish, Louisiana     2012                                              26004
# St. Landry Parish, Louisiana  2012                                                 **
# St. Tammany Parish, Louisiana 2012                                              13836
# Tangipahoa Parish, Louisiana  2012                                              21256
#
# [5 rows x 120 columns]

# %%
# Merge and reset index to create main dataframe
president_income = president.merge(income, left_on='county', right_on='county', how='left')
president_income = president_income.reset_index().set_index(['year_x','county'])


# Isolate [year] Median Income and [year] Standard Error data
median_col = income.columns.str.contains('year')
Median_Income = income.iloc[:,median_col]
error_col = income.columns.str.contains('year')
Standard_Error = income.iloc[:,error_col]


# Change Median and Error data to have 'State', 'year', and Median/Error in specified columns
median = pd.melt(income, id_vars='county',value_vars=income.columns[median_col],var_name='year')
error = pd.melt(income, id_vars='county',value_vars=income.columns[error_col],var_name='year')


# Edit column names to match data change above
median['year'] = median['year'].str.replace('Median Income','')
median = median.rename(columns = {'value':'Median Income'})
error['year'] = error['year'].str.replace('Standard Error','')
error = error.rename(columns = {'value':'Standard Error'})


#Edit 'State' to match 'state' in main dataframe
median = median.rename(columns = {'State':'state'})
error = error.rename(columns = {'State':'state'})

median['year'] = pd.to_numeric(median['year'])
error['year'] = pd.to_numeric(median['year'])

median = median.set_index(['year','state'])
error = error.set_index(['year','state'])

president_income = president_income.reset_index()
politics = president_income[['year','state','office','candidate', 'party', 'writein', 'candidatevotes', 'totalvotes']].copy()

median = median.reset_index()
error = error.reset_index()


# Merge Median Income and Standard Error columns into main dataframe
income_politics_table = politics.merge(median, on=['year','state'], how='outer')
income_politics_table = income_politics_table.merge(error, on=['year','state'], how='outer')
ipt = income_politics_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-2453357a1927> in <module>
#       1 # Merge and reset index to create main dataframe
#       2 president_income = president.merge(income, left_on='county', right_on='county', how='left')
# ----> 3 president_income = president_income.reset_index().set_index(['year_x','county'])
#       4
#       5
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['year_x'] are in the columns"
